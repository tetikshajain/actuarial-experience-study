# %% [markdown]
# # Canada Mortality Table Analysis
#
# This notebook processes and explores a Canadian life table dataset.
# The goal is to transform the raw actuarial life table into a clean dataset that can be used for mortality modeling and insurance risk analysis.
#
# ## Objectives
#
# 1. Extract male and female mortality tables from the raw Excel dataset
# 2. Clean and standardize actuarial variables
# 3. Create a unified mortality dataset
# 4. Perform exploratory analysis of mortality patterns
#
# ## Key Variables
#
# | Variable | Description |
# |--------|-------------|
# age | Age in years |
# survivors_lx | Number of individuals surviving to age x |
# deaths_dx | Number of deaths between age x and x+1 |
# mortality_rate_qx | Probability of death between age x and x+1 |
# survival_probability_px | Probability of surviving one additional year |
# life_expectancy_ex | Expected remaining lifetime at age x |
#
# ## Exploratory Analysis
#
# The notebook visualizes:
#
# - Mortality rate by age
# - Life expectancy trends
# - Survivorship curves
#
# These analyses help illustrate fundamental mortality patterns used in insurance pricing.

# %%
# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Dataset

life_raw = pd.read_excel("../data/raw/canada_life_table.xlsx", sheet_name="2019", header=None)
life_raw.iloc[15:40]
# Out:
#      0                                                  1                2   \
# 15  NaN                                                NaN              NaN
# 16  NaN  Complete life table / Table complète de mortalité              NaN
# 17  NaN                                             Canada              NaN
# 18  NaN                                               2019              NaN
# 19  NaN                                     Males / Hommes              NaN
# 20  NaN                                          Age / Âge               lx
# 21  NaN                                                NaN  number / nombre
# 22  NaN                                      0 year / 0 an           100000
# 23  NaN                                      1 year / 1 an            99511
# 24  NaN                                    2 years / 2 ans            99485
# 25  NaN                                    3 years / 3 ans            99467
# 26  NaN                                    4 years / 4 ans            99453
# 27  NaN                                    5 years / 5 ans            99442
# 28  NaN                                    6 years / 6 ans            99433
# 29  NaN                                    7 years / 7 ans            99425
# 30  NaN                                    8 years / 8 ans            99418
# 31  NaN                                    9 years / 9 ans            99410
# 32  NaN                                  10 years / 10 ans            99403
# 33  NaN                                  11 years / 11 ans            99395
# 34  NaN                                  12 years / 12 ans            99386
# 35  NaN                                  13 years / 13 ans            99376
# 36  NaN                                  14 years / 14 ans            99362
# 37  NaN                                  15 years / 15 ans            99345
# 38  NaN                                  16 years / 16 ans            99321
# 39  NaN                                  17 years / 17 ans            99288
#
#      3                          4         5        6                7   \
# 15  NaN                        NaN       NaN      NaN              NaN
# 16  NaN                        NaN       NaN      NaN              NaN
# 17  NaN                        NaN       NaN      NaN              NaN
# 18  NaN                        NaN       NaN      NaN              NaN
# 19  NaN                        NaN       NaN      NaN              NaN
# 20   dx                         qx  m.e.(qx)       px               Lx
# 21  NaN  probability / probabilité       NaN      NaN  number / nombre
# 22  489                    0.00489   0.00031  0.99511            99551
# 23   26                    0.00026   0.00007  0.99974            99500
# 24   18                    0.00019   0.00006  0.99981            99473
# 25   14                    0.00014   0.00005  0.99986            99459
# 26   11                    0.00011   0.00005  0.99989            99446
# 27    9                    0.00009   0.00004  0.99991            99438
# 28    8                    0.00008   0.00004  0.99992            99429
# 29    7                    0.00007   0.00004  0.99993            99421
# 30    7                    0.00007   0.00004  0.99993            99414
# 31    7                    0.00007   0.00004  0.99993            99407
# 32    8                    0.00008   0.00004  0.99992            99399
# 33    9                    0.00009   0.00004  0.99991            99391
# 34   11                    0.00011   0.00004  0.99989            99381
# 35   13                    0.00013   0.00005  0.99987            99369
# 36   17                    0.00018   0.00006  0.99982            99354
# 37   24                    0.00024   0.00007  0.99976            99333
# 38   33                    0.00033   0.00008  0.99967            99304
# 39   42                    0.00043   0.00009  0.99957            99267
#
#          8             9   ...  \
# 15      NaN           NaN  ...
# 16      NaN           NaN  ...
# 17      NaN           NaN  ...
# 18      NaN           NaN  ...
# 19      NaN           NaN  ...
# 20       Tx            ex  ...
# 21      NaN  year / année  ...
# 22  8010812         80.11  ...
# 23  7911262          79.5  ...
# 24  7811762         78.52  ...
# 25  7712289         77.54  ...
# 26  7612829         76.55  ...
# 27  7513383         75.56  ...
# 28  7413946         74.56  ...
# 29  7314517         73.57  ...
# 30  7215095         72.57  ...
# 31  7115681         71.58  ...
# 32  7016274         70.58  ...
# 33  6916875         69.59  ...
# 34  6817484          68.6  ...
# 35  6718103          67.6  ...
# 36  6618734         66.61  ...
# 37  6519381         65.62  ...
# 38  6420048         64.64  ...
# 39  6320743         63.66  ...
#
#                                                    23               24   25  \
# 15                                                NaN              NaN  NaN
# 16  Complete life table / Table complète de mortalité              NaN  NaN
# 17                                             Canada              NaN  NaN
# 18                                               2019              NaN  NaN
# 19                            Both sexes / Deux sexes              NaN  NaN
# 20                                          Age / Âge               lx   dx
# 21                                                NaN  number / nombre  NaN
# 22                                      0 year / 0 an           100000  439
# 23                                      1 year / 1 an            99561   24
# 24                                    2 years / 2 ans            99537   17
# 25                                    3 years / 3 ans            99520   13
# 26                                    4 years / 4 ans            99506   11
# 27                                    5 years / 5 ans            99496    9
# 28                                    6 years / 6 ans            99487    8
# 29                                    7 years / 7 ans            99479    7
# 30                                    8 years / 8 ans            99472    7
# 31                                    9 years / 9 ans            99465    7
# 32                                  10 years / 10 ans            99458    7
# 33                                  11 years / 11 ans            99450    8
# 34                                  12 years / 12 ans            99442   10
# 35                                  13 years / 13 ans            99433   12
# 36                                  14 years / 14 ans            99421   15
# 37                                  15 years / 15 ans            99406   21
# 38                                  16 years / 16 ans            99385   28
# 39                                  17 years / 17 ans            99357   35
#
#                            26        27       28               29       30  \
# 15                        NaN       NaN      NaN              NaN      NaN
# 16                        NaN       NaN      NaN              NaN      NaN
# 17                        NaN       NaN      NaN              NaN      NaN
# 18                        NaN       NaN      NaN              NaN      NaN
# 19                        NaN       NaN      NaN              NaN      NaN
# 20                         qx  m.e.(qx)       px               Lx       Tx
# 21  probability / probabilité       NaN      NaN  number / nombre      NaN
# 22                    0.00439   0.00021  0.99561            99599  8222807
# 23                    0.00024   0.00005  0.99976            99549  8123208
# 24                    0.00017   0.00004  0.99983            99527  8023659
# 25                    0.00013   0.00004  0.99987            99513  7924132
# 26                    0.00011   0.00003  0.99989            99500  7824619
# 27                    0.00009   0.00003  0.99991            99491  7725119
# 28                    0.00008   0.00003  0.99992            99483  7625627
# 29                    0.00007   0.00003  0.99993            99475  7526145
# 30                    0.00007   0.00003  0.99993            99468  7426669
# 31                    0.00007   0.00003  0.99993            99461  7327201
# 32                    0.00007   0.00003  0.99993            99454  7227740
# 33                    0.00008   0.00003  0.99992            99446  7128286
# 34                     0.0001   0.00003   0.9999            99437  7028840
# 35                    0.00012   0.00003  0.99988            99427  6929402
# 36                    0.00015   0.00004  0.99985            99413  6829975
# 37                    0.00021   0.00004  0.99979            99395  6730562
# 38                    0.00028   0.00005  0.99972            99371  6631167
# 39                    0.00035   0.00006  0.99965            99340  6531796
#
#               31        32
# 15           NaN       NaN
# 16           NaN       NaN
# 17           NaN       NaN
# 18           NaN       NaN
# 19           NaN       NaN
# 20            ex  m.e.(ex)
# 21  year / année       NaN
# 22         82.23      0.05
# 23         81.59      0.04
# 24         80.61      0.04
# 25         79.62      0.04
# 26         78.63      0.04
# 27         77.64      0.04
# 28         76.65      0.04
# 29         75.66      0.04
# 30         74.66      0.04
# 31         73.67      0.04
# 32         72.67      0.04
# 33         71.68      0.04
# 34         70.68      0.04
# 35         69.69      0.04
# 36          68.7      0.04
# 37         67.71      0.04
# 38         66.72      0.04
# 39         65.74      0.04
#
# [25 rows x 33 columns]

# %%
# Separating Columns into Male & Female Information

male_table = life_raw.iloc[21:133, 1:11].copy()
male_table.columns = ["age","lx","dx","qx","mx","px","Lx","Tx","ex","mex"]
male_table["sex"] = "male"

female_table = life_raw.iloc[21:133, 12:22].copy()
female_table.columns = ["age","lx","dx","qx","mx","px","Lx","Tx","ex","mex"]
female_table["sex"] = "female"

# Combining Information to Clean Table

mortality_table = pd.concat([male_table, female_table])
mortality_table = mortality_table.reset_index(drop=True)
mortality_table = mortality_table.drop(index=0, axis=0)
mortality_table
# Out:
#                                         age      lx   dx       qx       mx  \
# 1                             0 year / 0 an  100000  489  0.00489  0.00031
# 2                             1 year / 1 an   99511   26  0.00026  0.00007
# 3                           2 years / 2 ans   99485   18  0.00019  0.00006
# 4                           3 years / 3 ans   99467   14  0.00014  0.00005
# 5                           4 years / 4 ans   99453   11  0.00011  0.00005
# ..                                      ...     ...  ...      ...      ...
# 219                     106 years / 106 ans     323  142  0.44149  0.07276
# 220                     107 years / 107 ans     180   83  0.46227  0.11899
# 221                     108 years / 108 ans      97   47  0.48193  0.18138
# 222                     109 years / 109 ans      50   25  0.50038  0.20944
# 223  110 years and over / \n110 ans et plus      25   25        1        0
#
#           px     Lx       Tx     ex   mex     sex
# 1    0.99511  99551  8010812  80.11  0.07    male
# 2    0.99974  99500  7911262   79.5  0.06    male
# 3    0.99981  99473  7811762  78.52  0.06    male
# 4    0.99986  99459  7712289  77.54  0.06    male
# 5    0.99989  99446  7612829  76.55  0.06    male
# ..       ...    ...      ...    ...   ...     ...
# 219  0.55851    251      537   1.66  0.24  female
# 220  0.53773    139      286   1.59  0.33  female
# 221  0.51807     74      147   1.52  0.41  female
# 222  0.49962     38       74   1.47   0.4  female
# 223        0     36       36   1.43     …  female
#
# [223 rows x 11 columns]

# %%
# Cleaning Table

mortality_table["age"] = (mortality_table["age"].astype(str).str.extract(r"(\d+)"))

mortality_table = mortality_table.dropna(subset=["age"])
mortality_table.loc[:, "age"] = mortality_table["age"].astype(int)

# Changing Header to Readable Headings

mortality_table = mortality_table.rename(columns={
    "lx": "survivors_lx",
    "dx": "deaths_dx",
    "qx": "mortality_rate_qx",
    "mx": "central_death_rate_mx",
    "px": "survival_probability_px",
    "Lx": "person_years_lived_Lx",
    "Tx": "total_future_years_Tx",
    "ex": "life_expectancy_ex",
    "mex": "std_error_life_expectancy"
})
mortality_table
# Out:
#      age survivors_lx deaths_dx mortality_rate_qx central_death_rate_mx  \
# 1      0       100000       489           0.00489               0.00031
# 2      1        99511        26           0.00026               0.00007
# 3      2        99485        18           0.00019               0.00006
# 4      3        99467        14           0.00014               0.00005
# 5      4        99453        11           0.00011               0.00005
# ..   ...          ...       ...               ...                   ...
# 219  106          323       142           0.44149               0.07276
# 220  107          180        83           0.46227               0.11899
# 221  108           97        47           0.48193               0.18138
# 222  109           50        25           0.50038               0.20944
# 223  110           25        25                 1                     0
#
#     survival_probability_px person_years_lived_Lx total_future_years_Tx  \
# 1                   0.99511                 99551               8010812
# 2                   0.99974                 99500               7911262
# 3                   0.99981                 99473               7811762
# 4                   0.99986                 99459               7712289
# 5                   0.99989                 99446               7612829
# ..                      ...                   ...                   ...
# 219                 0.55851                   251                   537
# 220                 0.53773                   139                   286
# 221                 0.51807                    74                   147
# 222                 0.49962                    38                    74
# 223                       0                    36                    36
#
#     life_expectancy_ex std_error_life_expectancy     sex
# 1                80.11                      0.07    male
# 2                 79.5                      0.06    male
# 3                78.52                      0.06    male
# 4                77.54                      0.06    male
# 5                76.55                      0.06    male
# ..                 ...                       ...     ...
# 219               1.66                      0.24  female
# 220               1.59                      0.33  female
# 221               1.52                      0.41  female
# 222               1.47                       0.4  female
# 223               1.43                         …  female
#
# [222 rows x 11 columns]

# %%
# Converting to Clean CSV table

mortality_table.to_csv("../data/processed/mortality_table.csv",index=False)

# %%
# Plotting Probability of Death VS Age

plt.figure(figsize=(10,6))

sns.lineplot(data=mortality_table,x="age",y="mortality_rate_qx",hue="sex")

plt.title("Mortality Rate by Age")
plt.xlabel("Age (years)")
plt.ylabel("Probability of Death")
plt.show()

# %%
# Plotting Expected Remaining Years VS Age

plt.figure(figsize=(10,6))

sns.lineplot(data=mortality_table,x="age",y="life_expectancy_ex",hue="sex")

plt.title("Remaining Life Expectancy by Age")
plt.xlabel("Age (years)")
plt.ylabel("Expected Remaining Years")
plt.show()

# %%
# Plotting Number of people alive VS Age
plt.figure(figsize=(10,6))

sns.lineplot(data=mortality_table,x="age",y="survivors_lx",hue="sex")

plt.title("Survivorship Curve by Age")
plt.xlabel("Age (years)")
plt.ylabel("Number of people alive")
plt.show()

# %% [markdown]
# Based on the plots, we can see that:
# - Probablity of Death increases as Age increases
# - Number of years remaining to live decreases as age increases
# - Number of people alive decreases as their age increases
